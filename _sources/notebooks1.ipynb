# %% [markdown]
# #Dissimilarty (Tugas 1)

# %% [markdown]
# -> Cari dataset dari url
#
# -> Tentukan dissimilarity
#
# -> Ukur Jarak d(1,2)
#
# -> Ukur Jarak d(1,3)
#
# -> Ukur Jarak d(1,4)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
url = 'https://raw.githubusercontent.com/AhmadSuud/jobsaleries/main/ds_salaries.csv'
data = pd.read_csv(url)

# %%
data.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %% [markdown]
# ## Menentukan Jarak Atribut Nominal

# %%
def diss (n,m):
  a = 2
  b = 0
  for col in ['salary','salary_in_usd']:
    if data[col][n] == data[col][m]:
      b+=1
  return (a-b)/a

# %%
print(diss(1,1))
print(diss(1,3))
print(diss(1,4))
# Out:
# 0.0
# 1.0
# 1.0
